# %% [markdown]
# # Sharpening
# By: Shawn Vosburg (260743167)
# Due: October 8th, 2018
# Class: ECSE 415, McGill University
# Assignment 1, sharpening.ipynb

# %% [markdown]
# ## Question 1.2 (Setup)
# *Import necessary libraries and create sharpening function according to function given in handout.*

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

#Create function to sharpen an image following forumla in assignment instructions
def sharpen(cleanImg, blurredImg):
    return 2*cleanImg - blurredImg

# %% [markdown]
# ## Question 1.2-1
# *Sharpen the given image ‘rice’ (see Figure 2(a)) where,
# • the blurred image is generated using 5 × 5 box filter. (3 points)
# • the blurred image is generated using 5 × 5 Gaussian filter with variance = 2 .*

# %%
#Q1.2
#Box sharpening
kernel = np.ones((5,5), np.float32)/(5*5)
rice = cv2.imread('rice.png',cv2.IMREAD_COLOR);
rice_BoxBlur = cv2.filter2D(rice, -1, kernel)
rice_box_sharp = sharpen(rice,rice_BoxBlur)


#Gaussian sharpening
rice = cv2.imread('rice.png',cv2.IMREAD_COLOR);
rice_GaussianBlur = cv2.GaussianBlur(rice,(5,5),sigmaX = 2, sigmaY = 2)
rice_gaussian_sharp = sharpen(rice,rice_GaussianBlur)


rice_plt = cv2.cvtColor(rice, cv2.COLOR_BGR2RGB)
rice_box_sharp_plt = cv2.cvtColor(rice_box_sharp, cv2.COLOR_BGR2RGB)
rice_gaussian_sharp_plt = cv2.cvtColor(rice_gaussian_sharp, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(20, 20))
plt.subplot(131), plt.imshow(rice_plt) 
plt.title("Rice Original"), plt.xticks([]), plt.yticks([])
plt.subplot(132), plt.imshow(rice_box_sharp_plt) 
plt.title("Rice BoxSharp"), plt.xticks([]), plt.yticks([])
plt.subplot(133), plt.imshow(rice_gaussian_sharp_plt) 
plt.title("Rice GaussSharp"), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Question1.2-2
# *Which of the two methods is expected to give better results and why?
# Can you observe expected result?*
#
# **Answer**: To sharpen an image is to make edges more prevalent in the image in order to more easily identify the objects. If a better result is considered to be with the one with the more sharpened edge, then the BOX SHARPENING is expected to giver better result as the gaussian blur takes into consideration less the surrounding pixels than the box filter. If the better result is the one that looks the most realistic, than the GAUSSIAN SHARPENING is expected to give better result as the the edges contrast less with the background.
